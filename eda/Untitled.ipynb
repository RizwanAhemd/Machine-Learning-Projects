# %% [markdown]
# # First step in eda
# ## Catorgorize cols
# ### - Numerical,Catgorical,mix type
# ### Numerical age,fare,passenger id
#
# ## Step 2:
#     - perform univariate analysis
#          Distribution analysis.
#     - Bi variate analysis
#     - Multivariate analysis
#     - Feature engineering
#     - Outlier detection

# %%
import pandas as pd
import seaborn as sns

# %%
data=sns.load_dataset('titanic')

# %%
data.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 848         0       2    male  28.0      0      1  33.0000        S  Second
# 806         0       1    male  39.0      0      0   0.0000        S   First
# 192         1       3  female  19.0      1      0   7.8542        S   Third
# 661         0       3    male  40.0      0      0   7.2250        C   Third
# 663         0       3    male  36.0      0      0   7.4958        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 848    man        True  NaN  Southampton    no  False
# 806    man        True    A  Southampton    no   True
# 192  woman       False  NaN  Southampton   yes  False
# 661    man        True  NaN    Cherbourg    no   True
# 663    man        True  NaN  Southampton    no   True

# %%
### First we can do univariate analysis
data['age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64
