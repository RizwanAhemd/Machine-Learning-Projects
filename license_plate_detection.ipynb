# %% [markdown]
# <a href="https://colab.research.google.com/github/RizwanAhemd/Machine-Learning-Projects/blob/main/license_plate_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

# %%
path = zipfile.ZipFile("/content/License Plate Recognition.v6i.yolov11.zip")

# %%
path.extractall()

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.9 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
pred=model.predict("/content/valid/images/021620_152b_jpeg_jpg.rf.f2037a2bab90c5b9159ee7ec0ec00732.jpg")
# Out:
# image 1/1 /content/valid/images/021620_152b_jpeg_jpg.rf.f2037a2bab90c5b9159ee7ec0ec00732.jpg: 640x640 2 cars, 7.9ms
# Speed: 12.2ms preprocess, 7.9ms inference, 36.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
pred[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
model.train(data="/content/data.yaml",epochs=30)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.predict("/content/131232-749706873_medium.mp4",save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/551) /content/131232-749706873_medium.mp4: 640x384 (no detections), 13.2ms
# video 1/1 (frame 2/551) /content/131232-749706873_medium.mp4: 640x384 (no detections), 14.1ms
# video 1/1 (frame 3/551) /content/131232-749706873_medium.mp4: 640x384 (no detections), 21.2ms
# video 1/1 (frame 4/551) /content/131232-749706873_medium.mp4: 640x384 (no detections), 8.5ms
# ...

# %%
model.predict("/content/licence_video.mp4",save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/635) /content/licence_video.mp4: 384x640 1 License-Plate, 9.9ms
# video 1/1 (frame 2/635) /content/licence_video.mp4: 384x640 1 License-Plate, 7.9ms
# video 1/1 (frame 3/635) /content/licence_video.mp4: 384x640 (no detections), 9.3ms
# video 1/1 (frame 4/635) /content/licence_video.mp4: 384x640 1 License-Plate, 13.8ms
# video 1/1 (frame 5/635) /content/licence_video.mp4: 384x640 1 License-Plate, 8.1ms
# ...
