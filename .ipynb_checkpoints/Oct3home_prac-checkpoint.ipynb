# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Real estate.csv')

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
df.duplicated().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.corr()
# Out:
#                                               No  X1 transaction date  \
# No                                      1.000000            -0.048658
# X1 transaction date                    -0.048658             1.000000
# X2 house age                           -0.032808             0.017549
# X3 distance to the nearest MRT station -0.013573             0.060880
# X4 number of convenience stores        -0.012699             0.009635
# X5 latitude                            -0.010110             0.035058
# X6 longitude                           -0.011059            -0.041082
# Y house price of unit area             -0.028587             0.087491
#
#                                         X2 house age  \
# No                                         -0.032808
# X1 transaction date                         0.017549
# X2 house age                                1.000000
# X3 distance to the nearest MRT station      0.025622
# X4 number of convenience stores             0.049593
# ...

# %%
df.head(2)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df.drop(["No",'X1 transaction date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
df.columns=("house_age","near_mrt","stores","latitude","longitude","price")

# %%
df.head()
# Out:
#    house_age   near_mrt  stores  latitude  longitude  price
# 0       32.0   84.87882      10  24.98298  121.54024   37.9
# 1       19.5  306.59470       9  24.98034  121.53951   42.2
# 2       13.3  561.98450       5  24.98746  121.54391   47.3
# 3       13.3  561.98450       5  24.98746  121.54391   54.8
# 4        5.0  390.56840       5  24.97937  121.54245   43.1

# %%
X=df.drop("price",axis=1)

# %%
y=df.price

# %%
X.shape
# Out:
# (414, 5)

# %%
y.shape
# Out:
# (414,)

# %%
# X.head()
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.20,random_state=123)

# %%
X_train.shape , y_train.shape, y_test.shape
# Out:
# ((331, 5), (331,), (83,))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
scaler.fit(X_train)
X_train_scaled=scaler.fit_transform(X_train)

# %%
X_train_scaled=scaler.transform(X_train)

# %%
X_test_scaled=scaler.transform(X_test)
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)

# %%
X_train_scaled.shape
# Out:
# (331, 5)

# %%
dt=pd.DataFrame(X_train_scaled,columns=X_train.columns)

# %%
X_train_scaled.shape
# Out:
# (331, 5)

# %%
from sklearn.linear_model import LinearRegression
model_scal=LinearRegression()

# %%
X_train_scaled.shape ,y_train.shape
# Out:
# ((331, 5), (331,))

# %%
model_scal.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
y_pred_train = model_scal.predict(X_train_scaled)
y_pred_test = model_scal.predict(X_test_scaled)
# Out:
# C:\Users\unite\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.5374293327415929

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.7070090312260635

# %%
mean_squared_error(y_train,y_pred_scaled)
# Out:
# 86.02662267595426

# %%
mean_squared_error(y_test,y_pred_test)
# Out:
# 52.53129113555216
