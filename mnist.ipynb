# %%
from tensorflow.keras.datasets import mnist

# %%
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
test_labels.shape
# Out:
# (10000,)

# %%
import matplotlib.pyplot as plt

# %%
digit=train_images[5]

# %%
plt.imshow(digit,cmap=plt.cm.binary)

# %%
from tensorflow.keras import layers
from tensorflow.keras import models

# %%
network = models.Sequential()

# %%
network.add(layers.Dense(512,activation='relu',input_shape=(784,)))
# Out:
# C:\Users\unite\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
network.add(layers.Dense(10,activation='softmax'))

# %%
network.compile(optimizer="rmsprop",loss='sparse_categorical_crossentropy',metrics=["accuracy"])

# %%
train_images=train_images.reshape((60000,784))

# %%
train_images=train_images.astype("float32")/255

# %%
test_images=test_images.reshape((10000,784))

# %%
test_images=test_images.astype("float32")/255

# %%
network.fit(train_images,train_labels,epochs=5,batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9253 - loss: 0.2622
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9682 - loss: 0.1076
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9787 - loss: 0.0708
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9851 - loss: 0.0506
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9888 - loss: 0.0380

# %%
# Out:
# 0

# %%
import joblib as jb

# %%
network.save('handwrittennumber.h5')  # creates a folder 'my_model'
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
