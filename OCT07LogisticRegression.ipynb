# %%
import pandas as pd

# %%
data=pd.read_csv('diabetes.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data=pd.read_csv('diabetes.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
data.head()

# %%
data.info()

# %%
data.duplicated().sum()

# %%
data.shape

# %%
data.Outcome.value_counts()

# %%
data.Outcome.unique()

# %%
X=data.drop('Outcome',axis=1)

# %%
y=data.Outcome

# %%
X.shape

# %%
y.shape

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234)
#
# NameError: name 'X' is not defined

# %%
X_train.shape , X_test.shape , y_train.shape , y_test.shape

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 lr=LogisticRegression()
#
# NameError: name 'LogisticRegression' is not defined

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 lr=LogisticRegression()
#       2 lr.fit(X_train,y_train)
#
# NameError: name 'LogisticRegression' is not defined

# %%
y_pred_train=lr.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 y_pred_train=lr.predict(X_train)
#
# NameError: name 'lr' is not defined

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
r2_score(y_train,y_pred_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 r2_score(y_train,y_pred_train)
#
# NameError: name 'r2_score' is not defined

# %%
precision_score(y_train,y_pred_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 precision_score(y_train,y_pred_train)
#
# NameError: name 'y_train' is not defined

# %%
recall_score(y_train,y_pred_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 recall_score(y_train,y_pred_train)
#
# NameError: name 'y_train' is not defined

# %%
f1_score(y_train,y_pred_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 f1_score(y_train,y_pred_train)
#
# NameError: name 'y_train' is not defined

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train,y_pred_train))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 from sklearn.metrics import classification_report
# ----> 2 print(classification_report(y_train,y_pred_train))
#
# NameError: name 'y_train' is not defined

# %%
class_1=data[data.Outcome==1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 class_1=data[data.Outcome==1]
#
# NameError: name 'data' is not defined

# %%
class_0=data[data.Outcome==0].sample(268)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 class_0=data[data.Outcome==0].sample(268)
#
# NameError: name 'data' is not defined

# %%
d1=pd.concat([class_0,class_1]).sample(536)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 d1=pd.concat([class_0,class_1]).sample(536)
#
# NameError: name 'class_0' is not defined

# %%
X=d1.drop('Outcome',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 X=d1.drop('Outcome',axis=1)
#
# NameError: name 'd1' is not defined

# %%
y=d1.Outcome
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 y=d1.Outcome
#
# NameError: name 'd1' is not defined

# %%
X.shape
# Out:
# (536, 8)

# %%
y.shape
# Out:
# (536,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1234)

# %%
X_train.shape , X_test.shape , y_train.shape , y_test.shape
# Out:
# ((428, 8), (108, 8), (428,), (108,))

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# C:\Users\unite\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred_train=lr.predict(X_train)
from sklearn.metrics import classification_report
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.71      0.72       204
#            1       0.74      0.77      0.76       224
#
#     accuracy                           0.74       428
#    macro avg       0.74      0.74      0.74       428
# weighted avg       0.74      0.74      0.74       428

# %% [markdown]
# ## Method to reduce Bias in data
# ### 1: removing the data from class which has more value like getting sample of equal
# ### 2: Synthetic

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(sampling_strategy='minority')

# %%
X,y=smote.fit_resample(X,y)

# %%
y.value_counts()
# Out:
# Outcome
# 1    268
# 0    268
# Name: count, dtype: int64

# %%
smote_data=pd.read_csv('diabetes.csv')

# %%
smote_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
smote_data.Outcome.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
X=smote_data.drop('Outcome',axis=1)

# %%
y=smote_data.Outcome

# %%
X.shape , y.shape
# Out:
# ((768, 8), (768,))

# %%
from sklearn.model_selection import train_test_split

# %%
from imblearn.over_sampling import SMOTE

# %%
smote=SMOTE(sampling_strategy='minority')

# %%
X,y=smote.fit_resample(X,y)

# %%
y.value_counts()
# Out:
# Outcome
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
474
